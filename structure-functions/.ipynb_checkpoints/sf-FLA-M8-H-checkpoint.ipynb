# %%
import time
start_time=time.time()

# %%
from pathlib import Path

from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import interpolate
import json

import strucfunc
from strucfunc import sosflog
import bfunc

# %% [markdown]
# Input path: velocity fields folder

# %%
reg = 'M8'
line = 'M8'

# %%
text_file_0 = open("path-data.txt", "r")
path_data = text_file_0.read()

# %%
datapath_data = Path(path_data).expanduser()

# %% [markdown]
# File names

# %%
name = 'FLA-M8-H'

# %%
data_in = json.load(open(str(datapath_data) + '/' + name + "-l.json"))

# %%
data=pd.DataFrame(data_in[name])

# %%
data.columns=['X','Y','RV','I','Sig']

# %%
sig = data.RV.std()
sig2 = data.RV.var()

# %%
box_size = np.sqrt((data.X.max()-data.X.min())*(data.Y.max()-data.Y.min()))*data_in['pc']*3600

# %%
table = sosflog(data,0.05,3600)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
table
# Out:
#            s                                                                 \
#        count         mean        std          min          25%          50%
# ils
# 0      120.0     7.615395   2.675158     0.791245     5.354829     7.782038
# 1       26.0    11.899253   0.433647    11.239235    11.529089    11.929682
# 2       40.0    13.271139   0.381883    12.654309    12.983676    13.227970
# 3       65.0    15.106282   0.504796    14.194495    14.650601    15.235433
# 4       64.0    16.861060   0.481953    15.893827    16.470948    16.879467
# 5       65.0    18.767554   0.613936    17.831891    18.263306    18.703968
# 6       94.0    21.133926   0.713545    19.974009    20.559569    21.049359
# 7      149.0    23.757493   0.748418    22.391707    23.144476    23.896595
# 8      145.0    26.602527   0.931322    25.145463    25.717873    26.633610
# 9      217.0    29.931188   1.000775    28.198337    29.168436    30.103572
# 10     265.0    33.488999   1.202438    31.623099    32.357067    33.359435
# 11     327.0    37.605463   1.302154    35.490129    36.400365    37.729424
# 12     476.0    42.308651   1.379651    39.843353    41.101329    42.360789
# 13     507.0    47.461096   1.528135    44.670129    46.153629    47.423435
# 14     656.0    53.319516   1.775524    50.119745    51.869602    53.401198
# 15     830.0    59.706159   2.012052    56.247980    57.999251    59.703365
# 16    1043.0    66.996783   2.188011    63.128150    65.058788    66.962711
# 17    1360.0    75.279347   2.507515    70.798404    73.129470    75.338339
# 18    1611.0    84.411037   2.854021    79.438952    81.984087    84.427727
# 19    2055.0    94.580431   3.196894    89.127334    91.646989    94.489685
# 20    2576.0   106.150995   3.529743   100.000364   103.011505   106.200249
# 21    3175.0   119.196577   3.901931   112.210819   115.876297   119.287084
# 22    3896.0   133.693177   4.375735   125.893335   130.052294   133.712254
# 23    4775.0   149.866790   4.947159   141.256644   145.615723   149.881232
# 24    5914.0   168.182126   5.609277   158.493231   163.322388   168.150821
# 25    7153.0   188.839478   6.263874   177.828089   183.481333   188.826407
# 26    8932.0   211.936180   6.985483   199.529508   205.874134   212.077523
# 27   11007.0   237.596724   7.906390   223.875011   230.868115   237.579306
# 28   13361.0   266.831628   8.869478   251.190298   259.263004   266.845299
# 29   16180.0   299.146766   9.976286   281.841978   290.607938   299.250487
# 30   19948.0   335.816824  11.066577   316.228045   326.190524   336.164312
# 31   23504.0   376.682806  12.488323   354.813395   365.796516   376.673758
# 32   28528.0   422.617920  14.012106   398.107397   410.398552   422.865353
# 33   33027.0   474.074523  15.621327   446.686592   460.723111   474.293627
# 34   38273.0   532.089988  17.627848   501.187427   516.837581   532.230557
# 35   43771.0   596.743624  19.744860   562.342072   579.662505   596.748136
# 36   49940.0   669.397718  22.230039   630.958333   650.090164   669.285731
# 37   53760.0   750.701785  24.929292   707.946198   729.175201   750.222646
# 38   55167.0   841.759662  27.973909   794.328850   817.308506   841.429951
# 39   54490.0   944.243805  31.421277   891.252505   916.733805   943.683459
# 40   50206.0  1058.719081  35.174751  1000.002065  1027.977250  1057.399950
# 41   43882.0  1187.167550  39.571850  1122.020841  1152.484405  1185.591813
# 42   36573.0  1331.237644  44.158638  1258.931196  1292.551776  1329.370318
# 43   27683.0  1492.773547  49.707161  1412.543414  1449.235863  1490.138735
# 44   19237.0  1674.100274  55.750832  1584.899151  1625.250831  1670.172001
# 45   12610.0  1876.276655  62.325909  1778.279491  1821.832011  1870.880098
# 46    7352.0  2103.268527  69.485850  1995.289009  2042.491398  2095.409421
# 47    3723.0  2353.588977  76.335297  2238.784477  2288.515556  2344.443930
# 48    1495.0  2640.803310  87.139694  2511.934924  2565.089090  2631.029427
# 49     422.0  2938.134203  88.008579  2818.545641  2864.839787  2920.114638
# 50      91.0  3277.607997  85.269642  3162.325937  3207.789080  3263.303416
#
#                                    dV2                                \
#              75%          max    count       mean        std     min
# ils
# 0      10.045809    11.164708    120.0   0.409772   0.758248  0.0001
# 1      12.341369    12.564621     26.0   0.697527   1.820734  0.0000
# 2      13.623515    14.109871     40.0   0.853840   1.197302  0.0016
# 3      15.594911    15.763344     65.0   0.760329   1.817199  0.0000
# 4      17.248060    17.749942     64.0   2.020712   8.162471  0.0000
# 5      19.314366    19.944610     65.0   1.061843   4.043230  0.0004
# 6      21.726269    22.367627     94.0   1.265853   3.162650  0.0000
# 7      24.339835    25.085167    149.0   1.180242   2.554835  0.0000
# 8      27.442664    28.179083    145.0   1.169299   2.027053  0.0000
# 9      30.736257    31.598310    217.0   1.731698   3.271394  0.0001
# 10     34.659689    35.479156    265.0   1.812959   3.426183  0.0000
# 11     38.772470    39.806962    327.0   2.363500   5.334493  0.0000
# 12     43.476668    44.663603    476.0   2.280906   5.532883  0.0001
# 13     48.833622    50.117323    507.0   2.518974   5.513267  0.0000
# 14     54.819165    56.231027    656.0   2.940861   8.565224  0.0000
# 15     61.474620    63.080177    830.0   2.699926   4.550823  0.0000
# 16     68.867067    70.792432   1043.0   3.683291   7.229523  0.0000
# 17     77.425161    79.431521   1360.0   4.151748  10.589893  0.0000
# 18     86.944452    89.124781   1611.0   4.332411   7.810893  0.0000
# 19     97.329409    99.995020   2055.0   3.931281   6.441973  0.0000
# 20    109.133451   112.201163   2576.0   4.728949   7.595330  0.0000
# 21    122.501821   125.892269   3175.0   5.517823   9.564075  0.0000
# 22    137.564002   141.241620   3896.0   6.085207   9.899623  0.0000
# 23    154.130707   158.486994   4775.0   6.566950  10.009238  0.0000
# 24    173.139828   177.814476   5914.0   7.324277  10.820844  0.0000
# 25    194.397356   199.526074   7153.0   8.071020  11.704524  0.0000
# 26    217.972840   223.869677   8932.0   8.949620  12.201324  0.0000
# 27    244.462209   251.186637  11007.0  10.271868  14.103592  0.0000
# 28    274.659586   281.833324  13361.0  11.543651  15.562603  0.0000
# 29    307.822061   316.220329  16180.0  12.579355  16.511017  0.0000
# 30    345.272616   354.811110  19948.0  13.489124  17.431926  0.0000
# 31    387.521610   398.106131  23504.0  14.090037  17.671832  0.0000
# 32    434.728349   446.680340  28528.0  14.458591  17.942710  0.0000
# 33    487.463116   501.185563  33027.0  13.944607  17.593255  0.0000
# 34    547.401138   562.340078  38273.0  13.106478  16.901516  0.0000
# 35    613.825963   630.954522  43771.0  12.210495  15.826631  0.0000
# 36    688.733725   707.945157  49940.0  11.558096  14.413878  0.0000
# 37    772.259099   794.324166  53760.0  11.683356  14.327663  0.0000
# 38    865.753052   891.250833  55167.0  12.727204  15.782145  0.0000
# 39    971.371186   999.997441  54490.0  14.752113  19.177543  0.0000
# 40   1088.831851  1122.012060  50206.0  16.378907  21.591629  0.0000
# 41   1220.968075  1258.912415  43882.0  18.057167  23.838143  0.0000
# 42   1368.611572  1412.533066  36573.0  19.572092  25.674659  0.0000
# 43   1534.826007  1584.889519  27683.0  24.228702  29.103670  0.0000
# 44   1721.317941  1778.277743  19237.0  28.650892  33.222974  0.0000
# 45   1927.750509  1995.218260  12610.0  29.820434  34.775496  0.0000
# 46   2161.609944  2238.616883   7352.0  33.067140  35.921657  0.0000
# 47   2412.774172  2511.856992   3723.0  37.435689  35.649033  0.0000
# 48   2709.491103  2817.835271   1495.0  44.428104  32.309250  0.0004
# 49   2997.238713  3157.629759    422.0  60.110459  32.193970  0.0009
# 50   3330.680800  3486.292858     91.0  66.226938  37.077398  0.0196
#
#
#            25%       50%        75%       max
# ils
# 0     0.022500   0.16810   0.465825    5.1529
# 1     0.036100   0.16850   0.473125    9.3025
# 2     0.088525   0.31925   1.152400    5.3361
# 3     0.052900   0.17640   0.504100    9.9856
# 4     0.062500   0.36665   0.805675   62.7264
# 5     0.072900   0.23040   0.722500   32.1489
# 6     0.026425   0.17640   0.688900   20.7936
# 7     0.108900   0.43560   1.060900   21.2521
# 8     0.067600   0.29160   1.322500   13.0321
# 9     0.067600   0.33640   1.392400   21.1600
# 10    0.084100   0.56250   1.612900   25.1001
# 11    0.108900   0.67240   2.280100   53.7289
# 12    0.127825   0.64000   2.287675   66.0969
# 13    0.144400   0.72250   2.560000   68.7241
# 14    0.211600   1.02010   2.797275  149.5729
# 15    0.220900   1.00000   3.312400   62.4100
# 16    0.216250   1.06090   4.223050   77.0884
# 17    0.240100   1.11305   4.090525  182.7904
# 18    0.302500   1.46410   5.290000  116.4241
# 19    0.270400   1.41610   4.796100   68.2276
# 20    0.360000   1.79560   5.569600   86.1184
# 21    0.372100   1.90440   6.604900  130.8736
# 22    0.448900   2.19040   7.182400  126.7876
# 23    0.547600   2.65690   8.294400  122.3236
# 24    0.608400   2.95840   9.594525  188.7876
# 25    0.608400   3.09760  10.824100  115.5625
# 26    0.792100   3.80250  12.816400  117.7225
# 27    0.864900   4.36810  14.899600  120.3409
# 28    0.980100   4.84000  16.810000  140.4225
# 29    1.102500   5.66440  18.490000  149.5729
# 30    1.299600   6.45160  19.713600  160.5289
# 31    1.440000   7.02250  20.976400  166.4100
# 32    1.716100   7.78410  20.793600  172.6596
# 33    1.742400   7.56250  19.536400  207.6481
# 34    1.638400   7.02250  17.977600  166.1521
# 35    1.440000   6.45160  16.974400  180.3649
# 36    1.440000   6.35040  16.402500  196.8409
# 37    1.537600   6.40090  16.810000  150.3076
# 38    1.587600   6.76000  17.892900  139.4761
# 39    1.690000   7.29000  19.980900  146.4100
# 40    1.638400   7.67290  22.562500  184.1449
# 41    1.822500   8.23690  24.900100  205.0624
# 42    2.073600   9.48640  26.316900  224.7001
# 43    3.027600  12.96000  34.810000  229.2196
# 44    3.422500  15.44490  43.033600  226.8036
# 45    3.385600  16.56490  44.355600  214.3296
# 46    6.438925  20.25000  48.580900  268.6321
# 47   11.088900  25.90810  55.204900  247.1184
# 48   18.062600  40.44960  64.883050  181.7104
# 49   39.721525  61.38725  81.540900  147.3796
# 50   46.105700  73.96000  89.683400  147.6225

# %%
s = 0.5 * (table[('s', 'min')] + table[('s', 'max')])*data_in['pc']
e_s = 0.5 * (table[('s', 'max')] - table[('s', 'min')])*data_in['pc']
b2 = table[('dV2', 'mean')]
ng = table[('dV2', 'count')]
e_b2 = table[('dV2', 'std')] / np.sqrt(ng)

# %%
r0 = np.interp(sig2, b2, s,period = 360)
r0
# Out:
# 1.052711441487156

# %%
r1 = np.interp(sig, b2, s,period = 360)
r1
# Out:
# 0.3544735567030707

# %%
r2 = np.interp(2*sig2, b2, s, period = 360)
r2
# Out:
# 5.859920534494883

# %%
#x = s
#y = b2 - sig2
#tck=interpolate.splrep(x,y,s=0)
#grid=np.linspace(x.min(),x.max(),num=len(x))
#ynew=interpolate.splev(grid,tck,der=0)
#inter=pd.DataFrame([grid,ynew]).T
#SFr=interpolate.sproot(tck)
#SFr

# %%
rgrid = np.linspace(s[0], s[:-1])

# %%
m = 1.0
s0 = data_in['s0']
noise = 0.01

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")


ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.axhline(2*sig2, ls=':')
ax.axvline(r2, ls=':')

ax.axhline(sig, ls=':')
ax.axvline(r1, ls=':')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="red")
ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation, pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

sig2, r0, m, s0, noise
# Out:
# (7.526433868794324, 1.052711441487156, 1.0, 0.002315988922497783, 0.01)

# %%
results = {
    'sig2' : sig2,
        'r0' : r0,
        'r1' : r1,
        'r2' : r2,
          }

# %%
data_export = {   
        's' : np.array(s),
        'b2' : np.array(b2),
        'pc' : data_in['pc'],
#        'pix' : data_in['pix'],
        's0' : data_in['s0'],
        'box_size': box_size,
         'results':results,
         'SF' : np.array(table),
        'VF' : data_in,
}

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
jsonfilename ="sf-" + name +".json"
with open(jsonfilename, "w") as f:
    json.dump(data_export, fp=f, indent=3, cls=MyEncoder)

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 7.8675103187561035 seconds ---

# %%
# !jupyter nbconvert --to script --no-prompt sf-FLA-M8-H.ipynb
# Out:
# [NbConvertApp] Converting notebook sf-FLA-M8-H.ipynb to script
# [NbConvertApp] Writing 3190 bytes to sf-FLA-M8-H.py
