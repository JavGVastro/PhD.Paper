# %%
import time
start_time=time.time()

# %%
from pathlib import Path

from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import interpolate
import json

import strucfunc
from strucfunc import sosflog
import bfunc

# %% [markdown]
# Input path: velocity fields folder

# %%
reg = 'M8'
line = 'M8'

# %%
text_file_0 = open("path-data.txt", "r")
path_data = text_file_0.read()

# %%
datapath_data = Path(path_data).expanduser()

# %% [markdown]
# File names

# %%
name = 'FLA-M8-N'

# %%
data_in = json.load(open(str(datapath_data) + '/' + name + "-l.json"))

# %%
data=pd.DataFrame(data_in[name])

# %%
data.columns=['X','Y','RV','I','Sig']

# %%
sig = data.RV.std()
sig2 = data.RV.var()

# %%
box_size = np.sqrt((data.X.max()-data.X.min())*(data.Y.max()-data.Y.min()))*data_in['pc']*3600

# %%
table = sosflog(data,0.05,3600)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
table
# Out:
#            s                                                                 \
#        count         mean        std          min          25%          50%
# ils
# 0      120.0     7.615395   2.675158     0.791245     5.354829     7.782038
# 1       26.0    11.899253   0.433647    11.239235    11.529089    11.929682
# 2       40.0    13.271139   0.381883    12.654309    12.983676    13.227970
# 3       65.0    15.106282   0.504796    14.194495    14.650601    15.235433
# 4       64.0    16.861060   0.481953    15.893827    16.470948    16.879467
# 5       65.0    18.767554   0.613936    17.831891    18.263306    18.703968
# 6       94.0    21.133926   0.713545    19.974009    20.559569    21.049359
# 7      149.0    23.757493   0.748418    22.391707    23.144476    23.896595
# 8      145.0    26.602527   0.931322    25.145463    25.717873    26.633610
# 9      217.0    29.931188   1.000775    28.198337    29.168436    30.103572
# 10     265.0    33.488999   1.202438    31.623099    32.357067    33.359435
# 11     327.0    37.605463   1.302154    35.490129    36.400365    37.729424
# 12     476.0    42.308651   1.379651    39.843353    41.101329    42.360789
# 13     507.0    47.461096   1.528135    44.670129    46.153629    47.423435
# 14     656.0    53.319516   1.775524    50.119745    51.869602    53.401198
# 15     830.0    59.706159   2.012052    56.247980    57.999251    59.703365
# 16    1043.0    66.996783   2.188011    63.128150    65.058788    66.962711
# 17    1360.0    75.279347   2.507515    70.798404    73.129470    75.338339
# 18    1611.0    84.411037   2.854021    79.438952    81.984087    84.427727
# 19    2055.0    94.580431   3.196894    89.127334    91.646989    94.489685
# 20    2576.0   106.150995   3.529743   100.000364   103.011505   106.200249
# 21    3175.0   119.196577   3.901931   112.210819   115.876297   119.287084
# 22    3896.0   133.693177   4.375735   125.893335   130.052294   133.712254
# 23    4775.0   149.866790   4.947159   141.256644   145.615723   149.881232
# 24    5914.0   168.182126   5.609277   158.493231   163.322388   168.150821
# 25    7153.0   188.839478   6.263874   177.828089   183.481333   188.826407
# 26    8932.0   211.936180   6.985483   199.529508   205.874134   212.077523
# 27   11007.0   237.596724   7.906390   223.875011   230.868115   237.579306
# 28   13361.0   266.831628   8.869478   251.190298   259.263004   266.845299
# 29   16180.0   299.146766   9.976286   281.841978   290.607938   299.250487
# 30   19948.0   335.816824  11.066577   316.228045   326.190524   336.164312
# 31   23504.0   376.682806  12.488323   354.813395   365.796516   376.673758
# 32   28528.0   422.617920  14.012106   398.107397   410.398552   422.865353
# 33   33027.0   474.074523  15.621327   446.686592   460.723111   474.293627
# 34   38273.0   532.089988  17.627848   501.187427   516.837581   532.230557
# 35   43771.0   596.743624  19.744860   562.342072   579.662505   596.748136
# 36   49940.0   669.397718  22.230039   630.958333   650.090164   669.285731
# 37   53760.0   750.701785  24.929292   707.946198   729.175201   750.222646
# 38   55167.0   841.759662  27.973909   794.328850   817.308506   841.429951
# 39   54490.0   944.243805  31.421277   891.252505   916.733805   943.683459
# 40   50206.0  1058.719081  35.174751  1000.002065  1027.977250  1057.399950
# 41   43882.0  1187.167550  39.571850  1122.020841  1152.484405  1185.591813
# 42   36573.0  1331.237644  44.158638  1258.931196  1292.551776  1329.370318
# 43   27683.0  1492.773547  49.707161  1412.543414  1449.235863  1490.138735
# 44   19237.0  1674.100274  55.750832  1584.899151  1625.250831  1670.172001
# 45   12610.0  1876.276655  62.325909  1778.279491  1821.832011  1870.880098
# 46    7352.0  2103.268527  69.485850  1995.289009  2042.491398  2095.409421
# 47    3723.0  2353.588977  76.335297  2238.784477  2288.515556  2344.443930
# 48    1495.0  2640.803310  87.139694  2511.934924  2565.089090  2631.029427
# 49     422.0  2938.134203  88.008579  2818.545641  2864.839787  2920.114638
# 50      91.0  3277.607997  85.269642  3162.325937  3207.789080  3263.303416
#
#                                    dV2                                \
#              75%          max    count       mean        std     min
# ils
# 0      10.045809    11.164708    120.0   0.863482   1.404199  0.0000
# 1      12.341369    12.564621     26.0   1.700235   2.846358  0.0100
# 2      13.623515    14.109871     40.0   1.857628   3.858191  0.0009
# 3      15.594911    15.763344     65.0   1.094691   1.547356  0.0016
# 4      17.248060    17.749942     64.0   3.770637  11.703486  0.0025
# 5      19.314366    19.944610     65.0   2.492618   6.400609  0.0016
# 6      21.726269    22.367627     94.0   4.027273   9.565446  0.0004
# 7      24.339835    25.085167    149.0   3.571787   8.286374  0.0001
# 8      27.442664    28.179083    145.0   2.482648   5.954039  0.0001
# 9      30.736257    31.598310    217.0   3.815924   9.018426  0.0000
# 10     34.659689    35.479156    265.0   5.247222  16.147882  0.0000
# 11     38.772470    39.806962    327.0   4.422908   9.915321  0.0001
# 12     43.476668    44.663603    476.0   5.129428  12.879636  0.0000
# 13     48.833622    50.117323    507.0   6.321202  13.827883  0.0001
# 14     54.819165    56.231027    656.0   5.635211  11.508036  0.0000
# 15     61.474620    63.080177    830.0   5.016172   9.085970  0.0000
# 16     68.867067    70.792432   1043.0   7.179070  13.612226  0.0001
# 17     77.425161    79.431521   1360.0   7.274219  13.273693  0.0000
# 18     86.944452    89.124781   1611.0   7.966011  13.993503  0.0000
# 19     97.329409    99.995020   2055.0   7.855884  13.429032  0.0000
# 20    109.133451   112.201163   2576.0   9.127206  14.360250  0.0000
# 21    122.501821   125.892269   3175.0   9.862972  15.811431  0.0000
# 22    137.564002   141.241620   3896.0  11.293220  17.027393  0.0000
# 23    154.130707   158.486994   4775.0  12.352937  17.620570  0.0000
# 24    173.139828   177.814476   5914.0  13.371219  19.004705  0.0000
# 25    194.397356   199.526074   7153.0  14.958183  20.753522  0.0000
# 26    217.972840   223.869677   8932.0  17.313501  23.378207  0.0000
# 27    244.462209   251.186637  11007.0  18.980748  26.236092  0.0000
# 28    274.659586   281.833324  13361.0  21.058467  29.768721  0.0000
# 29    307.822061   316.220329  16180.0  24.020662  33.283278  0.0000
# 30    345.272616   354.811110  19948.0  25.406621  36.372505  0.0000
# 31    387.521610   398.106131  23504.0  26.693469  38.382889  0.0000
# 32    434.728349   446.680340  28528.0  26.746983  38.228759  0.0000
# 33    487.463116   501.185563  33027.0  26.213674  38.003379  0.0000
# 34    547.401138   562.340078  38273.0  25.627060  36.450441  0.0000
# 35    613.825963   630.954522  43771.0  23.507558  32.920193  0.0000
# 36    688.733725   707.945157  49940.0  21.229960  29.341483  0.0000
# 37    772.259099   794.324166  53760.0  19.313179  26.474231  0.0000
# 38    865.753052   891.250833  55167.0  18.119805  25.570723  0.0000
# 39    971.371186   999.997441  54490.0  18.485200  25.536758  0.0000
# 40   1088.831851  1122.012060  50206.0  19.159111  26.122179  0.0000
# 41   1220.968075  1258.912415  43882.0  20.132040  27.246430  0.0000
# 42   1368.611572  1412.533066  36573.0  19.104083  26.854914  0.0000
# 43   1534.826007  1584.889519  27683.0  18.727047  26.262834  0.0000
# 44   1721.317941  1778.277743  19237.0  21.596512  28.001414  0.0000
# 45   1927.750509  1995.218260  12610.0  22.579368  27.460062  0.0000
# 46   2161.609944  2238.616883   7352.0  24.551148  28.771275  0.0000
# 47   2412.774172  2511.856992   3723.0  31.394274  33.307385  0.0000
# 48   2709.491103  2817.835271   1495.0  37.880423  37.464065  0.0000
# 49   2997.238713  3157.629759    422.0  50.893187  37.414312  0.0000
# 50   3330.680800  3486.292858     91.0  54.890031  36.668654  0.0144
#
#
#            25%       50%        75%       max
# ils
# 0     0.035175   0.22100   0.934675    6.9169
# 1     0.129900   0.53330   1.749925   11.6281
# 2     0.126700   0.40345   1.847025   21.5296
# 3     0.108900   0.40960   1.188100    6.2500
# 4     0.182775   0.54800   1.961200   89.8704
# 5     0.152100   0.54760   1.562500   44.4889
# 6     0.072900   0.28645   2.251200   54.9081
# 7     0.102400   0.59290   2.340900   55.0564
# 8     0.260100   0.86490   2.280100   49.5616
# 9     0.168100   0.72250   3.204100   85.7476
# 10    0.115600   0.72250   3.763600  164.6089
# 11    0.230400   1.41610   4.285000   94.8676
# 12    0.202500   1.10250   4.161600  184.1449
# 13    0.220900   1.23210   5.784050  139.9489
# 14    0.313600   1.71610   5.255575  130.4164
# 15    0.291600   1.58760   5.198400   84.4561
# 16    0.518400   2.22010   7.344100  181.9801
# 17    0.435600   2.22010   7.142275  118.3744
# 18    0.490000   2.40250   8.910250  155.0025
# 19    0.577600   2.85610   8.791250  139.2400
# 20    0.656100   3.27610  11.441325  115.7776
# 21    0.705600   3.76360  11.730650  144.7209
# 22    0.864900   4.04010  14.440000  146.6521
# 23    1.123600   5.29000  16.402500  157.2516
# 24    1.188100   5.56960  18.147600  203.3476
# 25    1.440000   6.60490  20.520900  216.9729
# 26    1.716100   8.29440  24.010000  236.8521
# 27    1.638400   8.52640  26.010000  224.1009
# 28    1.876900   9.30250  27.878400  261.4689
# 29    2.160900  10.56250  32.832900  285.6100
# 30    1.988100  10.56250  33.524100  292.7521
# 31    2.102500  10.95610  34.251775  307.3009
# 32    2.371600  11.15560  35.283600  353.4400
# 33    2.433600  11.28960  34.574400  375.1969
# 34    2.528100  11.49210  33.640000  378.3025
# 35    2.464900  11.08890  30.691600  340.7716
# 36    2.464900  10.49760  28.090000  362.5216
# 37    2.160900   9.61000  26.419600  336.7225
# 38    1.960000   8.76160  24.800400  341.8801
# 39    1.822500   8.64360  25.300900  340.4025
# 40    1.960000   9.06010  26.112100  362.1409
# 41    2.131600   9.73440  27.641325  367.8724
# 42    1.960000   8.88040  25.300900  359.1025
# 43    1.768900   8.41000  24.900100  293.0944
# 44    2.689600  10.82410  28.944400  290.3616
# 45    2.856100  11.42440  32.604100  202.4929
# 46    3.880900  14.13760  34.928100  203.9184
# 47    6.502500  19.53640  45.091250  197.4025
# 48    9.455850  26.41960  55.353600  207.9364
# 49   22.326300  45.96840  71.952975  193.7664
# 50   30.777650  56.10010  79.567300  152.7696

# %%
s = 0.5 * (table[('s', 'min')] + table[('s', 'max')])*data_in['pc']
e_s = 0.5 * (table[('s', 'max')] - table[('s', 'min')])*data_in['pc']
b2 = table[('dV2', 'mean')]
ng = table[('dV2', 'count')]
e_b2 = table[('dV2', 'std')] / np.sqrt(ng)

# %%
r0 = np.interp(sig2, b2, s,period = 360)
r0
# Out:
# 0.7587261931955411

# %%
r1 = np.interp(sig, b2, s,period = 360)
r1
# Out:
# 0.13470049524681882

# %%
r2 = np.interp(2*sig2, b2, s, period = 360)
r2
# Out:
# 2.347325485529594

# %%
#x = s
#y = b2 - sig2
#tck=interpolate.splrep(x,y,s=0)
#grid=np.linspace(x.min(),x.max(),num=len(x))
#ynew=interpolate.splev(grid,tck,der=0)
#inter=pd.DataFrame([grid,ynew]).T
#SFr=interpolate.sproot(tck)
#SFr

# %%
rgrid = np.linspace(s[0], s[:-1])

# %%
m = 1.0
s0 = data_in['s0']
noise = 0.01

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")


ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.axhline(2*sig2, ls=':')
ax.axvline(r2, ls=':')

ax.axhline(sig, ls=':')
ax.axvline(r1, ls=':')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="red")
ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation, pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

sig2, r0, m, s0, noise
# Out:
# (10.468659374077292, 0.7587261931955411, 1.0, 0.002315988922497783, 0.01)

# %%
results = {
    'sig2' : sig2,
        'r0' : r0,
        'r1' : r1,
        'r2' : r2,
          }

# %%
data_export = {   
        's' : np.array(s),
        'b2' : np.array(b2),
        'pc' : data_in['pc'],
#        'pix' : data_in['pix'],
        's0' : data_in['s0'],
        'box_size': box_size,
         'results':results,
         'SF' : np.array(table),
        'VF' : data_in,
}

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
jsonfilename ="sf-" + name +".json"
with open(jsonfilename, "w") as f:
    json.dump(data_export, fp=f, indent=3, cls=MyEncoder)

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 7.91848087310791 seconds ---

# %%
# !jupyter nbconvert --to script --no-prompt sf-FLA-M8-N.ipynb
# Out:
# [NbConvertApp] Converting notebook sf-FLA-M8-N.ipynb to script
# [NbConvertApp] Writing 3195 bytes to sf-FLA-M8-N.py
