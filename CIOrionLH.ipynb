# %%
import time

# %%
start_time = time.time()

# %%
import cmasher as cmr
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import lmfit
import json
import astropy.units as u
import bfunc
import pandas as pd
import corner
from scipy import interpolate
import pickle
import bplot

# %% [markdown]
# Data load and region parameters

# %%
data = "OrionLH"

# %%
name = "EON"

# %%
pickle_in = open("Results//SF" + data + ".pkl", "rb")
SFresults = pickle.load(pickle_in)

# %%
mask = SFresults["SF"]["N pairs"] > 0

# %%
B = SFresults["b2"][mask]
r = SFresults["s"][mask]
pc = SFresults["pc"]
# pix =  SFresults['pix']
box_size = SFresults["box_size"]
pc_per_arcsec = pc

# %% [markdown]
# # Merge first K points
# K = 3
# r[K] = np.mean(r[:K])
# B[K] = np.mean(B[:K])
# r = r[K:]
# B = B[K:]

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.01 * box_size, max=2.5 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
model.set_param_hint("sig2", value=0.5 * B.max(), min=0.0001 * B.max(), max=2 * B.max())

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.25, max=3.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.001 * pc_per_arcsec, max=3.0 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3.5 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#              r0       sig2     m        s0      noise
# value  0.309168   6.641159  1.00  0.059632   1.505818
# min    0.030917   0.001328  0.25  0.000119   0.000000
# max    7.729201  26.564638  3.00  0.357792  10.540726

# %%
relative_uncertainty = 0.075
weights = 1.0 / (relative_uncertainty * B)
large_scale = r > 0.85 * box_size
weights[large_scale] /= 3.0
# weights[:3] /= 3.0

# %%
to_fit = ~large_scale
result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
result
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>111</td><td></td></tr><tr><td># data points</td><td>21</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 8.92016403</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.55751025</td><td></td></tr><tr><td>Akaike info crit.</td><td>-7.98037016</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2.75775797</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  0.49001910 </td><td>  0.17027708 </td><td> (34.75%) </td><td> 0.3091680526242516 </td><td>  0.03091681 </td><td>  7.72920132 </td><td> True </td></tr><tr><td> sig2 </td><td>  3.32678406 </td><td>  47.5298368 </td><td> (1428.70%) </td><td> 6.641159452788554 </td><td>  0.00132823 </td><td>  26.5646378 </td><td> True </td></tr><tr><td> m </td><td>  1.78419117 </td><td>  0.38525102 </td><td> (21.59%) </td><td> 1.0 </td><td>  0.25000000 </td><td>  3.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  1.1926e-04 </td><td>  0.29550781 </td><td> (247775.17%) </td><td> 0.059632082776472924 </td><td>  1.1926e-04 </td><td>  0.35779250 </td><td> True </td></tr><tr><td> noise </td><td>  5.86066577 </td><td>  2.92103090 </td><td> (49.84%) </td><td> 1.5058180608837046 </td><td>  0.00000000 </td><td>  10.5407264 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>s0</td><td>1.0000</td></tr><tr><td>s0</td><td>noise</td><td>0.9870</td></tr><tr><td>sig2</td><td>noise</td><td>0.9860</td></tr><tr><td>r0</td><td>sig2</td><td>-0.9674</td></tr><tr><td>r0</td><td>s0</td><td>-0.9667</td></tr><tr><td>r0</td><td>noise</td><td>-0.9240</td></tr><tr><td>r0</td><td>m</td><td>0.1796</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[large_scale], B[large_scale], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# emcee

# %%
emcee_kws = dict(
    steps=10000, burn=500, thin=50, is_weighted=True, progress=False, workers=16
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# The chain is shorter than 50 times the integrated autocorrelation time for 5 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 200;
# tau: [589.17836981 636.12190018 294.36746862 543.58539631 204.70900914]

# %%
result_emcee
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>emcee</td><td></td></tr><tr><td># function evals</td><td>1000000</td><td></td></tr><tr><td># data points</td><td>21</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 12.0825236</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.75515772</td><td></td></tr><tr><td>Akaike info crit.</td><td>-1.60800963</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 3.61460256</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  0.38981659 </td><td>  0.13122927 </td><td> (33.66%) </td><td> 0.49001910174950325 </td><td>  0.03091681 </td><td>  7.72920132 </td><td> True </td></tr><tr><td> sig2 </td><td>  4.96040879 </td><td>  3.16445292 </td><td> (63.79%) </td><td> 3.326784063742991 </td><td>  0.00132823 </td><td>  26.5646378 </td><td> True </td></tr><tr><td> m </td><td>  1.65049854 </td><td>  0.61781537 </td><td> (37.43%) </td><td> 1.7841911700045587 </td><td>  0.25000000 </td><td>  3.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.12808967 </td><td>  0.09904588 </td><td> (77.33%) </td><td> 0.00011926449530853754 </td><td>  1.1926e-04 </td><td>  0.35779250 </td><td> True </td></tr><tr><td> noise </td><td>  6.07646492 </td><td>  0.51345514 </td><td> (8.45%) </td><td> 5.860665766000368 </td><td>  0.00000000 </td><td>  10.5407264 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>s0</td><td>0.7373</td></tr><tr><td>r0</td><td>sig2</td><td>-0.6862</td></tr><tr><td>r0</td><td>s0</td><td>-0.6174</td></tr><tr><td>m</td><td>noise</td><td>0.5736</td></tr><tr><td>r0</td><td>m</td><td>0.2616</td></tr><tr><td>s0</td><td>noise</td><td>0.2433</td></tr><tr><td>sig2</td><td>m</td><td>-0.2228</td></tr><tr><td>r0</td><td>noise</td><td>0.2093</td></tr><tr><td>sig2</td><td>noise</td><td>-0.1300</td></tr></table>

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass

# %%
bplot.corner_plot(
    result_emcee, result_emcee, name, data, data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]
)
# data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]

# %%
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
bplot.strucfunc_plot(
    result_emcee, result_emcee, r, B, to_fit, name, data, box_size, large_scale
)

# %%
CIresults = {
    "result_emcee": result_emcee,
    "result": result,
    "r": r,
    "B": B,
    "to_fit": to_fit,
    "name": name,
    "data": data,
    "box_size": box_size,
    "large_scale": large_scale,
}

# %%
data = "OrionLH"

# %%
f = open("Results//CI" + data + ".pkl", "wb")
pickle.dump(CIresults, f)
f.close()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 74.67392635345459 seconds ---
