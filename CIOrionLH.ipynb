# %%
import time

# %%
start_time = time.time()

# %%
import cmasher as cmr
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import lmfit
import json
import astropy.units as u
import bfunc
import pandas as pd
import corner
from scipy import interpolate
import pickle
import bplot

# %% [markdown]
# Data load and region parameters

# %%
data = "OrionLH"

# %%
name = "EON"

# %%
pickle_in = open("Results//SF" + data + ".pkl", "rb")
SFresults = pickle.load(pickle_in)

# %%
mask = SFresults["SF"]["N pairs"] > 0

# %%
B = SFresults["b2"][mask]
r = SFresults["s"][mask]
pc = SFresults["pc"]
# pix =  SFresults['pix']
box_size = SFresults["box_size"]
pc_per_arcsec = pc

# %% [markdown]
# # Merge first K points
# K = 3
# r[K] = np.mean(r[:K])
# B[K] = np.mean(B[:K])
# r = r[K:]
# B = B[K:]

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.005 * box_size, max=1.5 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
model.set_param_hint("sig2", value=0.5 * B.max(), min=0.0 * B.max(), max=1.5* B.max())

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.8, max=3.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.1 * pc_per_arcsec, max=4.0 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3.0 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#              r0       sig2    m        s0     noise
# value  0.309168   6.641159  1.0  0.059632  1.505818
# min    0.015458   0.000000  0.8  0.011926  0.000000
# max    4.637521  19.923478  3.0  0.477057  9.034908

# %%
relative_uncertainty = 0.03
weights = 1.0 / (relative_uncertainty * B)
large_scale = r > 0.65 * box_size
weights[large_scale] /= 3.0
weights[:5] /= 3.0

# %%
to_fit = ~large_scale
result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
result
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>253</td><td></td></tr><tr><td># data points</td><td>19</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 3.92111650</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.28007975</td><td></td></tr><tr><td>Akaike info crit.</td><td>-19.9831884</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-15.2609935</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  0.35341749 </td><td>  0.07304980 </td><td> (20.67%) </td><td> 0.3091680526242516 </td><td>  0.01545840 </td><td>  4.63752079 </td><td> True </td></tr><tr><td> sig2 </td><td>  7.67653024 </td><td>  3.48409019 </td><td> (45.39%) </td><td> 6.641159452788554 </td><td>  0.00000000 </td><td>  19.9234784 </td><td> True </td></tr><tr><td> m </td><td>  1.58082520 </td><td>  0.30979973 </td><td> (19.60%) </td><td> 1.0 </td><td>  0.80000000 </td><td>  3.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.23317523 </td><td>  0.09146109 </td><td> (39.22%) </td><td> 0.059632082776472924 </td><td>  0.01192642 </td><td>  0.47705666 </td><td> True </td></tr><tr><td> noise </td><td>  6.22217953 </td><td>  0.26200731 </td><td> (4.21%) </td><td> 1.5058180608837046 </td><td>  0.00000000 </td><td>  9.03490837 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>s0</td><td>0.9714</td></tr><tr><td>r0</td><td>sig2</td><td>-0.9474</td></tr><tr><td>r0</td><td>s0</td><td>-0.8492</td></tr><tr><td>m</td><td>noise</td><td>0.6970</td></tr><tr><td>m</td><td>s0</td><td>0.6187</td></tr><tr><td>sig2</td><td>m</td><td>0.4451</td></tr><tr><td>s0</td><td>noise</td><td>0.3978</td></tr><tr><td>sig2</td><td>noise</td><td>0.1833</td></tr><tr><td>r0</td><td>m</td><td>-0.1752</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[large_scale], B[large_scale], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# emcee

# %%
emcee_kws = dict(
    steps=100000, burn=500, thin=50, is_weighted=True, progress=False, workers=16
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)

# %%
result_emcee
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>emcee</td><td></td></tr><tr><td># function evals</td><td>10000000</td><td></td></tr><tr><td># data points</td><td>19</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 10.0292157</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.71637255</td><td></td></tr><tr><td>Akaike info crit.</td><td>-2.13979486</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 2.58240004</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  0.35109777 </td><td>  0.09086752 </td><td> (25.88%) </td><td> 0.35341748662480826 </td><td>  0.01545840 </td><td>  4.63752079 </td><td> True </td></tr><tr><td> sig2 </td><td>  8.97570708 </td><td>  4.49494461 </td><td> (50.08%) </td><td> 7.676530238309125 </td><td>  0.00000000 </td><td>  19.9234784 </td><td> True </td></tr><tr><td> m </td><td>  1.69229812 </td><td>  0.53947267 </td><td> (31.88%) </td><td> 1.5808251953521912 </td><td>  0.80000000 </td><td>  3.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.26203444 </td><td>  0.09531995 </td><td> (36.38%) </td><td> 0.23317522755621134 </td><td>  0.01192642 </td><td>  0.47705666 </td><td> True </td></tr><tr><td> noise </td><td>  6.26288656 </td><td>  0.47340222 </td><td> (7.56%) </td><td> 6.222179529025522 </td><td>  0.00000000 </td><td>  9.03490837 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>r0</td><td>sig2</td><td>-0.8280</td></tr><tr><td>sig2</td><td>s0</td><td>0.7862</td></tr><tr><td>r0</td><td>s0</td><td>-0.6204</td></tr><tr><td>m</td><td>noise</td><td>0.5811</td></tr><tr><td>s0</td><td>noise</td><td>0.4230</td></tr><tr><td>m</td><td>s0</td><td>0.4074</td></tr><tr><td>r0</td><td>m</td><td>0.2835</td></tr><tr><td>r0</td><td>noise</td><td>0.2825</td></tr></table>

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass
# Out:
# Autocorrelation time for the parameters:
# ----------------------------------------
# r0 = 1181.564
# sig2 = 1152.801
# m = 274.336
# s0 = 1114.116
# noise = 262.870

# %%
bplot.corner_plot(
    result_emcee, result_emcee, name, data, data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]
)
# data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]

# %%
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
bplot.strucfunc_plot(
    result_emcee, result_emcee, r, B, to_fit, name, data, box_size, large_scale
)

# %%
CIresults = {
    "result_emcee": result_emcee,
    "result": result,
    "r": r,
    "B": B,
    "to_fit": to_fit,
    "name": name,
    "data": data,
    "box_size": box_size,
    "large_scale": large_scale,
}

# %%
data = "OrionLH"

# %%
f = open("Results//CI" + data + ".pkl", "wb")
pickle.dump(CIresults, f)
f.close()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 813.506914138794 seconds ---
