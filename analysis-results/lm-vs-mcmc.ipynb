# %%
import time
start_time=time.time()
from pathlib import Path
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import math
import json
from matplotlib.patches import Circle, PathPatch
import mpl_toolkits.mplot3d.art3d as art3d

sns.set_context("talk")

# %%
from results import loadresults,loadresults2

# %%
x,y = loadresults('sample-names-corr','formal-names-corr','2sig')

# %%
x
# Out:
#      Region  s0 [RMS]  s0+[RMS]  s0-[RMS]  s0 [FWHM]  s0- [FWHM]  s0+ [FWHM]  \
# 0   NGC 604  2.107818  1.035290  0.785156   1.216317    0.453074    0.597414
# 1   NGC 595  0.407243  0.619146 -0.005555   0.235000   -0.003206    0.357278
# 2  Hubble X  0.362383  0.329451  0.106297   0.351311    0.103049    0.319384
# 3  Hubble V  0.341152  0.534050  0.060209   0.330728    0.058369    0.517732
# 4    30 Dor  0.157696  0.087443  0.045208   1.528771    0.438271    0.847708
# 5    Carina  0.007489  0.007641  0.006069   1.704157    1.381130    1.738878
# 6   NGC 346  0.111505  0.026608  0.018193   0.871755    0.142235    0.208022
# 7        M8  0.006984  0.001892  0.006169   2.708257    2.392325    0.733499
# 8     Orion  0.002030  0.000263  0.000209   2.399523    0.247326    0.310434
#
#             bn        bn+      bn-
# 0  3.274804e-01  0.701433  0.307106
# 1  1.537175e+00  1.705241  1.050606
# 2  3.211300e-01  0.415344  0.279438
# 3  3.548363e-10  0.653923 -0.009842
# ...

# %%
y
# Out:
#      Region        sig2      sig2+      sig2-         r0       r0+       r0-  \
# 0   NGC 604   85.868750  20.418004  11.463602  12.087616  6.443078  3.955140
# 1   NGC 595   53.206356   4.643371   1.916528  11.211662  0.739236  0.851215
# 2  Hubble X   14.812259   2.672278   0.682873   4.099418  0.325858  0.187655
# 3  Hubble V    9.824044   3.534439   0.502361   3.561965  0.451416  1.269954
# 4    30 Dor  297.536688  39.611347  18.518779   3.857852  1.064497  0.468204
# 5    Carina   18.137617   1.393893   1.527513   0.550457  0.082150  0.065909
# 6   NGC 346   33.022801   2.568073   1.487357   2.373683  0.293811  0.159564
# 7        M8    7.385188   1.242835   0.743911   1.034714  0.236500  0.122820
# 8     Orion   12.648003   0.742833   0.521982   0.067959  0.006121  0.004111
#
#           m        m+        m-
# 0  0.775075  0.207397  0.226706
# 1  1.376368  0.087961  0.149309
# 2  1.016097  0.080615  0.222241
# 3  0.810433  0.093346  0.283010
# 4  0.851961  0.077782  0.138921
# ...

# %%
a,b = loadresults2('sample-names-corr','formal-names-corr','LM')

# %%
c,d = loadresults2('sample-names-corr','formal-names-corr','MCMC')

# %%
a
# Out:
#      Region  s0 [RMS]  s0+[RMS]  s0 [FWHM]  s0+ [FWHM]           bn   \
# 0   NGC 604  2.107818  1.276000   1.216317    0.736316  3.274804e-01
# 1   NGC 595  0.407243  0.209656   0.235000    0.120982  1.537175e+00
# 2  Hubble X  0.362383  0.173768   0.351311    0.168458  3.211300e-01
# 3  Hubble V  0.341152  0.294993   0.330728    0.285980  3.548363e-10
# 4    30 Dor  0.157696  0.030939   1.528771    0.299933  6.155564e+00
# 5    Carina  0.007489  1.191873   1.704157  271.233600  2.256934e+00
# 6   NGC 346  0.111505  0.008015   0.871755    0.062660  8.402099e-01
# 7        M8  0.006984  0.723727   2.708257  280.645435  4.366590e-01
# 8     Orion  0.002030  0.000113   2.399523    0.133966  2.515480e-02
#
#          bn+
# 0   0.380672
# 1   0.952484
# 2   0.333569
# 3   0.712798
# 4   0.803967
# 5  49.845536
# 6   0.027369
# 7   4.099369
# 8   0.002331

# %%
c
# Out:
#      Region  s0 [RMS]  s0+[RMS]  s0 [FWHM]  s0+ [FWHM]       bn        bn+
# 0   NGC 604  2.398038  0.537534   1.383789    0.310184  0.366008  0.284348
# 1   NGC 595  0.542906  0.147281   0.313284    0.084989  1.874313  0.713417
# 2  Hubble X  0.411558  0.117587   0.398983    0.113994  0.382661  0.197684
# 3  Hubble V  0.501518  0.161582   0.486194    0.156644  0.231863  0.187568
# 4    30 Dor  0.167937  0.032560   1.628059    0.315654  6.251980  0.795319
# 5    Carina  0.008350  0.004928   1.900120    1.121549  2.463191  1.234625
# 6   NGC 346  0.113856  0.011269   0.890140    0.088101  0.842922  0.035627
# 7        M8  0.004855  0.002895   1.882503    1.122783  0.410514  0.131309
# 8     Orion  0.002046  0.000120   2.419258    0.141439  0.025260  0.002512

# %%
#plt.rcParams["axes.edgecolor"] = "yellow"
#plt.rcParams["axes.linewidth"]  = 2

fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(projection='3d')

#t = np.arange(0, 2*np.pi+.1, 0.01)
#x, y, z = np.sin(t), np.cos(3*t), np.sin(5*t)
#estep = 15
#i = np.arange(t.size)
#zuplims = (i % estep == 0) & (i // estep % 3 == 0)
#zlolims = (i % estep == 0) & (i // estep % 3 == 2)
#ax.errorbar(x, y, z, 0.2, zuplims=zuplims, zlolims=zlolims, errorevery=estep)

#ax.errorbar(b['sig2'],b['r0'],b['m'], 0.2, zuplims=10, zlolims=-10)

ax.scatter(b['sig2'],b['r0'],b['m'],marker='o',s=150,color='b', alpha = 0.75)
#ax.scatter(b['sig2']+b['sig2+'],b['r0']+b['r0+'],b['m']+b['m+'],marker='.',s=100,color='blue')
#ax.scatter(b['sig2']-b['sig2+'],b['r0']-b['r0+'],b['m']-b['m+'],marker='.',s=100,color='blue')

#ax.scatter(d['sig2'],d['r0'],d['m'],marker='o',s=150,color='red')
#ax.scatter(d['sig2']+d['sig2+'],d['r0']+d['r0+'],d['m']+d['m+'],marker='.',s=100,color='red')
#ax.scatter(d['sig2']-d['sig2+'],d['r0']-d['r0+'],d['m']-d['m+'],marker='.',s=100,color='red')

p = Circle((6, 1), 0.1)
ax.add_patch(p)
art3d.pathpatch_2d_to_3d(p, z=0, zdir="x")

ax.set_xlabel('log sig2')
ax.set_ylabel('log r0')
ax.set_zlabel('m')
#ax.set_xlim(0, 1)
#ax.set_ylim(0, 1)
#ax.set_zlim(0.7, 1.5)

#ax.view_init(elev=30, azim=-45)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,7))

#lower_error =  b['sig2-']
#upper_error =  b['sig2+']
#asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
#plt.errorbar(b['sig2'], b['r0'], xerr=asymmetric_error, yerr=b['r0+'], ls=" ", elinewidth=2.5, alpha=0.5)

ax.scatter(b['sig2'],b['r0'], c="b",s=100, alpha=0.55, label="LM", marker = 'o')
ax.errorbar(b['sig2'],b['r0'], xerr=b['sig2+'], yerr=b['r0+'], ls=" ", elinewidth=2.5, alpha=0.3)
ax.scatter(d['sig2'],d['r0'], c="r",s=100, alpha=0.3, label="MCMC", marker = 'o')
ax.errorbar(d['sig2'],d['r0'], xerr=d['sig2+'], yerr=d['r0+'], ls=" ", elinewidth=2.5, alpha=0.55)
#ax.scatter(y['sig2'],y['r0'], c="r",s=40, alpha=0.6)
#ax.errorbar(y['sig2'],y['r0'], xerr=y['sig2+'], yerr=y['r0+'], ls=" ", elinewidth=0.5, alpha=1.0, c="g")


ax.set(#xscale='log', yscale='log', 
       xlabel='$σ_{pos}^2$',
       ylabel='r0'
      )

plt.legend()

plt.savefig('Imgs//lm_vs_mcmc_1.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(7,7))

ax.scatter(a['s0 [FWHM]'],b['m'], c="b",s=100, alpha=0.55, label="LM", marker = 'o')
ax.errorbar(a['s0 [FWHM]'],b['m'], xerr=a['s0+ [FWHM]'], yerr=b['m+'], ls=" ", elinewidth=2.5, alpha=0.3)
#ax.scatter(d['sig2'],d['m'], c="r",s=100, alpha=0.3, label="MCMC", marker = 'o')
#ax.errorbar(d['sig2'],d['m'], xerr=d['sig2+'], yerr=d['m+'], ls=" ", elinewidth=2.5, alpha=0.55)
ax.scatter(c['s0 [FWHM]'],d['m'], c="r",s=100, alpha=0.3, label="MCMC", marker = 'o')
ax.errorbar(c['s0 [FWHM]'],d['m'], xerr=c['s0+ [FWHM]'], yerr=d['m+'], ls=" ", elinewidth=2.5, alpha=0.55)
#ax.scatter(y['sig2'],y['r0'], c="r",s=40, alpha=0.6)
#ax.errorbar(y['sig2'],y['r0'], xerr=y['sig2+'], yerr=y['r0+'], ls=" ", elinewidth=0.5, alpha=1.0, c="g")


ax.set(#xscale='log', yscale='log', 
       xlabel='$s0 [RMS]$',
       ylabel='m'
      )

plt.legend()

plt.savefig('Imgs//lm_vs_mcmc_2.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(7,7))

ax.scatter(a['s0 [FWHM]'],a['bn '], c="b",s=100, alpha=0.55, label="LM", marker = 'o')
ax.errorbar(a['s0 [FWHM]'],a['bn '], xerr=a['s0+ [FWHM]'], yerr=a['bn+'], ls=" ", elinewidth=2.5, alpha=0.3)
#ax.scatter(d['sig2'],d['m'], c="r",s=100, alpha=0.3, label="MCMC", marker = 'o')
#ax.errorbar(d['sig2'],d['m'], xerr=d['sig2+'], yerr=d['m+'], ls=" ", elinewidth=2.5, alpha=0.55)
ax.scatter(c['s0 [FWHM]'],c['bn '], c="r",s=100, alpha=0.3, label="MCMC", marker = 'o')
ax.errorbar(c['s0 [FWHM]'],c['bn '], xerr=c['s0+ [FWHM]'], yerr=c['bn+'], ls=" ", elinewidth=2.5, alpha=0.55)
#ax.scatter(y['sig2'],y['r0'], c="r",s=40, alpha=0.6)
#ax.errorbar(y['sig2'],y['r0'], xerr=y['sig2+'], yerr=y['r0+'], ls=" ", elinewidth=0.5, alpha=1.0, c="g")


ax.set(#xscale='log', yscale='log', 
       xlabel='$s0 [RMS]$',
       ylabel='noise'
      )

ax.set_xlim(0, 3)
ax.set_ylim(-1, 7)

plt.legend()

plt.savefig('Imgs//lm_vs_mcmc_3.pdf', bbox_inches='tight')

# %%
# !jupyter nbconvert --to script --no-prompt results-compiler-v2.ipynb
# Out:
# [NbConvertApp] Converting notebook results-compiler-v2.ipynb to script
# [NbConvertApp] Writing 2254 bytes to results-compiler-v2.py
