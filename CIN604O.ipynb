# %%
import time

# %%
start_time = time.time()

# %%
import cmasher as cmr
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import lmfit
import json
import astropy.units as u
import bfunc
import pandas as pd
import corner
from scipy import interpolate
import pickle
import bplot

# %% [markdown]
# Data load and region parameters

# %%
data = "N604O"

# %%
name = 'NGC 604 [OIII]'

# %%
pickle_in = open("Results//SF" + data + ".pkl", "rb")
SFresults = pickle.load(pickle_in)

# %%
mask = SFresults["SF"]["N pairs"] > 0

# %%
B = SFresults["b2"][mask]
r = SFresults["s"][mask]
pc = SFresults["pc"]
pix = SFresults["pix"]
box_size = SFresults["box_size"]
pc_per_arcsec = pc

# %% [markdown]
# # Merge first K points
# K = 1
# r[K] = np.mean(r[:K])
# B[K] = np.mean(B[:K])
# r = r[K:]
# B = B[K:]

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.05 * box_size, max=2.0 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
model.set_param_hint("sig2", value=0.5 * B.max(), min=0.01 * B.max(), max=2.0 * B.max())

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.5, max=2.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.1 * pc_per_arcsec, max=4.0 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#                r0        sig2    m         s0     noise
# value   15.667510   43.812574  1.0   2.036217  0.527623
# min      7.833755    0.876251  0.5   0.407243  0.000000
# max    313.350196  175.250294  2.0  16.289740  3.165738

# %%
relative_uncertainty = 0.055
weights = 1.0 / (relative_uncertainty * B)
large_scale = r > 0.3 * box_size
weights[large_scale] /= 2.0
weights[:3] /= 2.5

# %%
to_fit = r <= 0.7 * box_size
#to_fit = ~large_scale
result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
result
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>65</td><td></td></tr><tr><td># data points</td><td>35</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 18.9542592</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.63180864</td><td></td></tr><tr><td>Akaike info crit.</td><td>-11.4661789</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-3.68943858</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  7.83375501 </td><td>  1.98333435 </td><td> (25.32%) </td><td> 15.66750982156535 </td><td>  7.83375491 </td><td>  313.350196 </td><td> True </td></tr><tr><td> sig2 </td><td>  53.8706064 </td><td>  13.0907841 </td><td> (24.30%) </td><td> 43.8125735036088 </td><td>  0.87625147 </td><td>  175.250294 </td><td> True </td></tr><tr><td> m </td><td>  1.16025827 </td><td>  0.20372282 </td><td> (17.56%) </td><td> 1.0 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  2.29779992 </td><td>  1.09299623 </td><td> (47.57%) </td><td> 2.036217460660051 </td><td>  0.40724349 </td><td>  16.2897397 </td><td> True </td></tr><tr><td> noise </td><td>  0.61520104 </td><td>  0.12714171 </td><td> (20.67%) </td><td> 0.5276230598221501 </td><td>  0.00000000 </td><td>  3.16573836 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>s0</td><td>0.9986</td></tr><tr><td>r0</td><td>s0</td><td>-0.9913</td></tr><tr><td>r0</td><td>sig2</td><td>-0.9856</td></tr><tr><td>sig2</td><td>m</td><td>-0.9830</td></tr><tr><td>m</td><td>s0</td><td>-0.9785</td></tr><tr><td>r0</td><td>m</td><td>0.9543</td></tr><tr><td>m</td><td>noise</td><td>0.2324</td></tr><tr><td>sig2</td><td>noise</td><td>-0.1377</td></tr><tr><td>s0</td><td>noise</td><td>-0.1152</td></tr><tr><td>r0</td><td>noise</td><td>0.1067</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[large_scale], B[large_scale], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# emcee

# %%
emcee_kws = dict(
    steps=10000, burn=500, thin=50, is_weighted=True, progress=False, workers=16
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
result_emcee
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>emcee</td><td></td></tr><tr><td># function evals</td><td>1000000</td><td></td></tr><tr><td># data points</td><td>35</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 19.3138468</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.64379489</td><td></td></tr><tr><td>Akaike info crit.</td><td>-10.8084021</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-3.03166179</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  8.76337495 </td><td>  0.71153582 </td><td> (8.12%) </td><td> 7.83375500979259 </td><td>  7.83375491 </td><td>  313.350196 </td><td> True </td></tr><tr><td> sig2 </td><td>  48.5037970 </td><td>  4.34098789 </td><td> (8.95%) </td><td> 53.87060637233966 </td><td>  0.87625147 </td><td>  175.250294 </td><td> True </td></tr><tr><td> m </td><td>  1.26964804 </td><td>  0.12468111 </td><td> (9.82%) </td><td> 1.1602582728202475 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  1.76570051 </td><td>  0.48051862 </td><td> (27.21%) </td><td> 2.2977999178805346 </td><td>  0.40724349 </td><td>  16.2897397 </td><td> True </td></tr><tr><td> noise </td><td>  0.58230591 </td><td>  0.16770086 </td><td> (28.80%) </td><td> 0.6152010417674024 </td><td>  0.00000000 </td><td>  3.16573836 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>s0</td><td>0.9639</td></tr><tr><td>sig2</td><td>m</td><td>-0.9299</td></tr><tr><td>m</td><td>s0</td><td>-0.9140</td></tr><tr><td>r0</td><td>s0</td><td>-0.8589</td></tr><tr><td>r0</td><td>sig2</td><td>-0.7461</td></tr><tr><td>r0</td><td>m</td><td>0.6547</td></tr><tr><td>r0</td><td>noise</td><td>-0.2887</td></tr><tr><td>s0</td><td>noise</td><td>0.2706</td></tr><tr><td>sig2</td><td>noise</td><td>0.1573</td></tr></table>

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass
# Out:
# Autocorrelation time for the parameters:
# ----------------------------------------
# r0 = 104.934
# sig2 = 107.366
# m = 104.395
# s0 = 113.056
# noise = 75.717

# %%
bplot.corner_plot(
    result_emcee, result, name, data, data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]
)

# %%
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
#bplot.strucfunc_plot(
#    result_emcee, result_emcee, r, B, to_fit, name, data, box_size, large_scale
#)

# %%
CIresults = {
    "result_emcee": result_emcee,
    "result": result,
    "r": r,
    "B": B,
    "to_fit": to_fit,
    "name": name,
    "data": data,
    "box_size": box_size,
    "large_scale": large_scale,
}

# %%
f = open("Results//CI" + data + ".pkl", "wb")
pickle.dump(CIresults, f)
f.close()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 80.59301161766052 seconds ---
