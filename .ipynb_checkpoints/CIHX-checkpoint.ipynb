# %%
import time

# %%
start_time = time.time()

# %%
import cmasher as cmr
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import lmfit
import json
import astropy.units as u
import bfunc
import pandas as pd
import corner
from scipy import interpolate
import pickle
import bplot

# %% [markdown]
# Data load and region parameters

# %%
data = "HX"

# %%
name = "Hubble X"

# %%
pickle_in = open("Results//SF" + data + ".pkl", "rb")
SFresults = pickle.load(pickle_in)

# %%
mask = SFresults["SF"]["N pairs"] > 0

# %%
B = SFresults["b2"][mask]
r = SFresults["s"][mask]
pc = SFresults["pc"]
pix = SFresults["pix"]
box_size = SFresults["box_size"]
pc_per_arcsec = pc

# %%
pc_per_arcsec
# Out:
# 2.42406840554768

# %% [markdown]
# Don't merge any points. That is only necessary for the MUSE sources.

# %% [markdown]
#  K = 0
#  r[K] = np.mean(r[:K])
#  B[K] = np.mean(B[:K])
#  r = r[K:]
#  B = B[K:]

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.05 * box_size, max=2.0 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
model.set_param_hint("sig2", value=0.5 * B.max(), min=0.25 * B.max(), max=2.0 * B.max())

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.5, max=2.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.1 * pc_per_arcsec, max=1.5 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#                r0       sig2    m        s0     noise
# value    7.803498  15.333366  1.0  1.212034  0.729269
# min      3.901749   7.666683  0.5  0.242407  0.000000
# max    156.069950  61.333466  2.0  3.636103  4.375614

# %%
relative_uncertainty = 0.035
weights = 1.0 / (relative_uncertainty * B)
large_scale = r > 0.25 * box_size
weights[large_scale] /= 2.0
weights[:4] /= 2.0

# %%
to_fit = r <= 0.6 * box_size
#to_fit = ~large_scale
result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
result
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>69</td><td></td></tr><tr><td># data points</td><td>36</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 20.6518305</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.66618808</td><td></td></tr><tr><td>Akaike info crit.</td><td>-10.0057393</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2.08814457</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  4.00847381 </td><td>  0.29739088 </td><td> (7.42%) </td><td> 7.803497517637758 </td><td>  3.90174876 </td><td>  156.069950 </td><td> True </td></tr><tr><td> sig2 </td><td>  15.8398801 </td><td>  1.05424621 </td><td> (6.66%) </td><td> 15.333366471785913 </td><td>  7.66668324 </td><td>  61.3334659 </td><td> True </td></tr><tr><td> m </td><td>  0.92491317 </td><td>  0.09032240 </td><td> (9.77%) </td><td> 1.0 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.52370458 </td><td>  0.17820086 </td><td> (34.03%) </td><td> 1.21203420277384 </td><td>  0.24240684 </td><td>  3.63610261 </td><td> True </td></tr><tr><td> noise </td><td>  0.48899810 </td><td>  0.20655023 </td><td> (42.24%) </td><td> 0.7292689457288082 </td><td>  0.00000000 </td><td>  4.37561367 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>m</td><td>-0.9786</td></tr><tr><td>sig2</td><td>s0</td><td>0.9603</td></tr><tr><td>m</td><td>s0</td><td>-0.9318</td></tr><tr><td>r0</td><td>s0</td><td>-0.8779</td></tr><tr><td>s0</td><td>noise</td><td>0.8064</td></tr><tr><td>r0</td><td>sig2</td><td>-0.7448</td></tr><tr><td>r0</td><td>m</td><td>0.7279</td></tr><tr><td>r0</td><td>noise</td><td>-0.7261</td></tr><tr><td>sig2</td><td>noise</td><td>0.6677</td></tr><tr><td>m</td><td>noise</td><td>-0.5906</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[large_scale], B[large_scale], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# emcee

# %%
emcee_kws = dict(
    steps=50000, burn=500, thin=50, is_weighted=True, progress=False, workers=16
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)

# %%
result_emcee
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>emcee</td><td></td></tr><tr><td># function evals</td><td>5000000</td><td></td></tr><tr><td># data points</td><td>36</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 20.8240996</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.67174515</td><td></td></tr><tr><td>Akaike info crit.</td><td>-9.70668759</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-1.78909290</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  4.12181723 </td><td>  0.17181135 </td><td> (4.17%) </td><td> 4.00847380566899 </td><td>  3.90174876 </td><td>  156.069950 </td><td> True </td></tr><tr><td> sig2 </td><td>  15.7381264 </td><td>  0.97959956 </td><td> (6.22%) </td><td> 15.839880086953013 </td><td>  7.66668324 </td><td>  61.3334659 </td><td> True </td></tr><tr><td> m </td><td>  0.93490872 </td><td>  0.08765923 </td><td> (9.38%) </td><td> 0.9249131743158063 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.48065240 </td><td>  0.13967743 </td><td> (29.06%) </td><td> 0.5237045845097021 </td><td>  0.24240684 </td><td>  3.63610261 </td><td> True </td></tr><tr><td> noise </td><td>  0.41759501 </td><td>  0.19963522 </td><td> (47.81%) </td><td> 0.48899809866672295 </td><td>  0.00000000 </td><td>  4.37561367 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>m</td><td>-0.9635</td></tr><tr><td>sig2</td><td>s0</td><td>0.9318</td></tr><tr><td>m</td><td>s0</td><td>-0.9096</td></tr><tr><td>s0</td><td>noise</td><td>0.5599</td></tr><tr><td>r0</td><td>s0</td><td>-0.3662</td></tr><tr><td>r0</td><td>noise</td><td>-0.3414</td></tr><tr><td>sig2</td><td>noise</td><td>0.3044</td></tr><tr><td>m</td><td>noise</td><td>-0.2374</td></tr><tr><td>r0</td><td>m</td><td>0.1326</td></tr><tr><td>r0</td><td>sig2</td><td>-0.1116</td></tr></table>

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass
# Out:
# Autocorrelation time for the parameters:
# ----------------------------------------
# r0 = 84.477
# sig2 = 151.585
# m = 134.115
# s0 = 137.167
# noise = 80.996

# %%
bplot.corner_plot(
    result_emcee, result_emcee, name, data, data_ranges=[0.95, 0.97, 0.995, 0.997, 0.999]
)

# %%
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
bplot.strucfunc_plot(
    result_emcee, result_emcee, r, B, to_fit, name, data, box_size, large_scale
)

# %%
CIresults = {'result_emcee': result_emcee,
            'result' : result,
             'r' : r,
             'B' : B,
             'to_fit': to_fit,
             'name' : name,
             'data' : data,
             'box_size' : box_size,
             'large_scale' : large_scale
          }

# %%
f = open("Results//CI" + data + ".pkl", "wb")
pickle.dump(CIresults, f)
f.close()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 356.0793311595917 seconds ---
