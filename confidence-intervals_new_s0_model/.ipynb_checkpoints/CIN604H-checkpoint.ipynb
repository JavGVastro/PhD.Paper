# %%
import time

# %%
start_time = time.time()

# %%
import cmasher as cmr
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import lmfit
import json
import astropy.units as u
import bfunc
import pandas as pd
import corner
from scipy import interpolate
import pickle
import bplot

# %% [markdown]
# Data load and region parameters

# %%
data = "N604H"

# %%
name = "NGC 604"

# %%
pickle_in = open("Results//SF" + data + ".pkl", "rb")
SFresults = pickle.load(pickle_in)

# %%
mask = SFresults["SF"]["N pairs"] > 0

# %%
B = SFresults["b2"][mask]
r = SFresults["s"][mask]
pc = SFresults["pc"]
pix = SFresults["pix"]
box_size = SFresults["box_size"]
pc_per_arcsec = pc

# %% [markdown]
# # Merge first K points
# K = 1
# r[K] = np.mean(r[:K])
# B[K] = np.mean(B[:K])
# r = r[K:]
# B = B[K:]

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.001 * box_size, max=2.0 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
model.set_param_hint("sig2", value=0.5 * B.max(), min=0.05 * B.max(), max=0.65 * B.max())

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.5, max=2.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.01 * pc_per_arcsec, max=3.0 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.05 * B.min(), min=0.0, max=3 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#                r0       sig2    m         s0     noise
# value   17.344190  71.404584  1.0   2.036217  0.095289
# min      0.173442   7.140458  0.5   0.040724  0.000000
# max    346.883801  92.825959  2.0  12.217305  5.717356

# %%
relative_uncertainty = 0.1
weights = 1.0 / (relative_uncertainty * B)
large_scale = r > 0.35 * box_size
weights[large_scale] /= 3.0
weights[:3] /= 2.5

# %%
to_fit = ~large_scale
result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
result
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>62</td><td></td></tr><tr><td># data points</td><td>30</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 10.2243648</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.40897459</td><td></td></tr><tr><td>Akaike info crit.</td><td>-22.2927141</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-15.2867272</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  16.4581607 </td><td>  6.81142856 </td><td> (41.39%) </td><td> 17.34419004181762 </td><td>  0.17344190 </td><td>  346.883801 </td><td> True </td></tr><tr><td> sig2 </td><td>  92.8259582 </td><td>  28.2030591 </td><td> (30.38%) </td><td> 71.40458379047428 </td><td>  7.14045838 </td><td>  92.8259589 </td><td> True </td></tr><tr><td> m </td><td>  0.76376424 </td><td>  0.30524268 </td><td> (39.97%) </td><td> 1.0 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  1.91592332 </td><td>  1.10427411 </td><td> (57.64%) </td><td> 2.036217460660051 </td><td>  0.04072435 </td><td>  12.2173048 </td><td> True </td></tr><tr><td> noise </td><td>  0.15686831 </td><td>  0.39045881 </td><td> (248.91%) </td><td> 0.09528925992088814 </td><td>  0.00000000 </td><td>  5.71735560 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>m</td><td>-0.9847</td></tr><tr><td>m</td><td>s0</td><td>-0.9822</td></tr><tr><td>sig2</td><td>s0</td><td>0.9486</td></tr><tr><td>r0</td><td>sig2</td><td>0.9393</td></tr><tr><td>r0</td><td>m</td><td>-0.8774</td></tr><tr><td>r0</td><td>s0</td><td>0.7864</td></tr><tr><td>r0</td><td>noise</td><td>-0.3623</td></tr><tr><td>sig2</td><td>noise</td><td>-0.2564</td></tr><tr><td>m</td><td>noise</td><td>0.2292</td></tr><tr><td>s0</td><td>noise</td><td>-0.1063</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[large_scale], B[large_scale], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# emcee

# %%
emcee_kws = dict(
    steps=25000, burn=500, thin=50, is_weighted=True, progress=False, workers=16
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
result_emcee
# Out:
# <h2> Model</h2> Model(bfunc03s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>emcee</td><td></td></tr><tr><td># function evals</td><td>2500000</td><td></td></tr><tr><td># data points</td><td>30</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 11.5632230</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.46252892</td><td></td></tr><tr><td>Akaike info crit.</td><td>-18.6010326</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-11.5950457</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  14.3782546 </td><td>  2.52430399 </td><td> (17.56%) </td><td> 16.458160677938785 </td><td>  0.17344190 </td><td>  346.883801 </td><td> True </td></tr><tr><td> sig2 </td><td>  88.0124641 </td><td>  4.76811231 </td><td> (5.42%) </td><td> 92.82595822669244 </td><td>  7.14045838 </td><td>  92.8259589 </td><td> True </td></tr><tr><td> m </td><td>  0.82249337 </td><td>  0.08148428 </td><td> (9.91%) </td><td> 0.7637642429551563 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  1.84702986 </td><td>  0.39708888 </td><td> (21.50%) </td><td> 1.9159233205455128 </td><td>  0.04072435 </td><td>  12.2173048 </td><td> True </td></tr><tr><td> noise </td><td>  0.46502890 </td><td>  0.38175178 </td><td> (82.09%) </td><td> 0.15686830784145622 </td><td>  0.00000000 </td><td>  5.71735560 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>m</td><td>s0</td><td>-0.7905</td></tr><tr><td>sig2</td><td>m</td><td>-0.6940</td></tr><tr><td>r0</td><td>s0</td><td>-0.6059</td></tr><tr><td>sig2</td><td>s0</td><td>0.4796</td></tr><tr><td>r0</td><td>sig2</td><td>0.3252</td></tr><tr><td>s0</td><td>noise</td><td>0.2113</td></tr><tr><td>r0</td><td>noise</td><td>-0.1497</td></tr><tr><td>r0</td><td>m</td><td>0.1449</td></tr></table>

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass
# Out:
# Autocorrelation time for the parameters:
# ----------------------------------------
# r0 = 84.064
# sig2 = 90.229
# m = 86.038
# s0 = 87.845
# noise = 80.719

# %%
bplot.corner_plot(
    result_emcee, result, name, data, data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]
)

# %%
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
#bplot.strucfunc_plot(
#    result_emcee, result_emcee, r, B, to_fit, name, data, box_size, large_scale
#)

# %%
CIresults = {
    "result_emcee": result_emcee,
    "result": result,
    "r": r,
    "B": B,
    "to_fit": to_fit,
    "name": name,
    "data": data,
    "box_size": box_size,
    "large_scale": large_scale,
}

# %%
f = open("Results//CI" + data + ".pkl", "wb")
pickle.dump(CIresults, f)
f.close()

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 183.9470658302307 seconds ---
