# %%
import time
start_time=time.time()

# %%
import cmasher as cmr
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import lmfit
import json
import astropy.units as u
import bfunc
import pandas as pd
import corner
from scipy import interpolate
import pickle
import bplot

# %% [markdown]
# Data load and region parameters

# %%
data = 'CarR'

# %%
name = 'Carina Red component'

# %%
pickle_in = open('Results//SF' + data + '.pkl',"rb")
SFresults = pickle.load(pickle_in)

# %%
#mask = SFresults['SF']["N pairs"] > 0

# %%
B = np.array(SFresults['b2'])#[mask]
r = np.array(SFresults['s'])#[mask]
pc =  SFresults['pc']
#pix =  SFresults['pix']
box_size =  SFresults['box_size']
pc_per_arcsec = pc

# %%
# Merge first K points
K = 7
r[K] = np.mean(r[:K])
B[K] = np.mean(B[:K])
r = r[K:]
B = B[K:]

# %%
model = lmfit.Model(bfunc.bfunc04s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise', 'box_size']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.01 * box_size, max=2 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
model.set_param_hint("sig2", value=0.5 * B.max(), min=0.25 * B.max(), max=2 * B.max())

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.5, max=2.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint("s0", value=0.5 * pc_per_arcsec, min=0.1 * pc_per_arcsec, max=1.5 * pc_per_arcsec)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3 * B.min())

# box_size is fixed
model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#               r0        sig2    m        s0       noise box_size
# value   1.966360   59.946764  1.0  0.005163   17.991069  19.6636
# min     0.196636   29.973382  0.5  0.001033    0.000000      NaN
# max    39.327198  239.787054  2.0  0.015490  107.946413      NaN
# vary         NaN         NaN  NaN       NaN         NaN    False

# %%
relative_uncertainty = 0.025
weights = 1.0 / (relative_uncertainty * B)
large_scale = r > 0.25 * box_size
weights[large_scale] /= 3.0
#weights[:3] /= 3.0

# %%
to_fit = ~large_scale
result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
result
# Out:
# <h2> Model</h2> Model(bfunc04s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>8628</td><td></td></tr><tr><td># data points</td><td>10</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 15.5225830</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.10451660</td><td></td></tr><tr><td>Akaike info crit.</td><td> 14.3971084</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 15.9100338</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  1.08384450 </td><td>  6.42188624 </td><td> (592.51%) </td><td> 1.9663599098314408 </td><td>  0.19663599 </td><td>  39.3271982 </td><td> True </td></tr><tr><td> sig2 </td><td>  74.7056036 </td><td>  327.951627 </td><td> (438.99%) </td><td> 59.946763569384615 </td><td>  29.9733818 </td><td>  239.787054 </td><td> True </td></tr><tr><td> m </td><td>  0.57900768 </td><td>  2.95099883 </td><td> (509.66%) </td><td> 1.0 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.01548980 </td><td>  0.11588281 </td><td> (748.12%) </td><td> 0.005163265703816558 </td><td>  0.00103265 </td><td>  0.01548980 </td><td> True </td></tr><tr><td> noise </td><td>  0.00527397 </td><td>  612.748703 </td><td> (11618361.39%) </td><td> 17.991068802034132 </td><td>  0.00000000 </td><td>  107.946413 </td><td> True </td></tr><tr><td> box_size </td><td>  19.6635991 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 19.663599098314407 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>sig2</td><td>m</td><td>-0.9997</td></tr><tr><td>s0</td><td>noise</td><td>0.9984</td></tr><tr><td>m</td><td>noise</td><td>0.9965</td></tr><tr><td>sig2</td><td>noise</td><td>-0.9950</td></tr><tr><td>r0</td><td>s0</td><td>0.9949</td></tr><tr><td>m</td><td>s0</td><td>0.9903</td></tr><tr><td>r0</td><td>noise</td><td>0.9894</td></tr><tr><td>sig2</td><td>s0</td><td>-0.9882</td></tr><tr><td>r0</td><td>m</td><td>0.9745</td></tr><tr><td>r0</td><td>sig2</td><td>-0.9702</td></tr></table>

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[large_scale], B[large_scale], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(result.params["box_size"].value, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(result.params["box_size"].value / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale = "log",
    yscale = "log",
    xlabel = "r [pc]",
    ylabel = r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine();

# %% [markdown]
# emcee

# %%
emcee_kws = dict(steps=5000, burn=500, thin=50, is_weighted=True,
                 progress=False, workers=16)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit], r=r[to_fit], weights=weights[to_fit], params=emcee_params, method='emcee',
    nan_policy='omit', fit_kws=emcee_kws,
)
# Out:
# C:\Users\ZAINTEL2\anaconda3\lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# The chain is shorter than 50 times the integrated autocorrelation time for 5 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 100;
# tau: [203.63958898 218.10726013 188.90418844 104.91116185 172.36901943]

# %%
result_emcee
# Out:
# <h2> Model</h2> Model(bfunc04s) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>emcee</td><td></td></tr><tr><td># function evals</td><td>500000</td><td></td></tr><tr><td># data points</td><td>10</td><td></td></tr><tr><td># variables</td><td>5</td><td></td></tr><tr><td>chi-square</td><td> 18.3164399</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.66328798</td><td></td></tr><tr><td>Akaike info crit.</td><td> 16.0521392</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 17.5650646</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> r0 </td><td>  1.12325959 </td><td>  0.32885158 </td><td> (29.28%) </td><td> 1.0838444966511993 </td><td>  0.19663599 </td><td>  39.3271982 </td><td> True </td></tr><tr><td> sig2 </td><td>  68.5210247 </td><td>  11.2820215 </td><td> (16.47%) </td><td> 74.70560361543284 </td><td>  29.9733818 </td><td>  239.787054 </td><td> True </td></tr><tr><td> m </td><td>  0.64714314 </td><td>  0.08861928 </td><td> (13.69%) </td><td> 0.579007678396684 </td><td>  0.50000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> s0 </td><td>  0.00921877 </td><td>  0.00492238 </td><td> (53.40%) </td><td> 0.01548979687779035 </td><td>  0.00103265 </td><td>  0.01548980 </td><td> True </td></tr><tr><td> noise </td><td>  5.28400038 </td><td>  5.12494679 </td><td> (96.99%) </td><td> 0.0052739683492945815 </td><td>  0.00000000 </td><td>  107.946413 </td><td> True </td></tr><tr><td> box_size </td><td>  19.6635991 </td><td>  </td><td> (96.99%) </td><td> 19.663599098314407 </td><td>        -inf </td><td>         inf </td><td> False </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>r0</td><td>sig2</td><td>0.9694</td></tr><tr><td>m</td><td>noise</td><td>0.8760</td></tr><tr><td>sig2</td><td>m</td><td>-0.6737</td></tr><tr><td>r0</td><td>m</td><td>-0.4912</td></tr><tr><td>sig2</td><td>noise</td><td>-0.4526</td></tr><tr><td>r0</td><td>noise</td><td>-0.2249</td></tr><tr><td>m</td><td>s0</td><td>-0.1033</td></tr></table>

# %%
plt.plot(result_emcee.acceptance_fraction, 'o')
plt.xlabel('walker')
plt.ylabel('acceptance fraction')
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f'{p} = {result_emcee.acor[i]:.3f}')
        except IndexError:
            pass

# %%
bplot.corner_plot(result_emcee, result, name, data, data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]);
#data_ranges=[0.95, 0.99, 0.995, 0.995, 0.999]

# %%
bplot.strucfunc_plot(result_emcee, r, B, to_fit, name, data, box_size, large_scale)

# %%
CIresults = {'result_emcee': result_emcee,
            'result' : result
          }

# %%
f = open('Results//CI' + data +'.pkl',"wb")
pickle.dump(CIresults,f)
f.close()

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 39.99794602394104 seconds ---
